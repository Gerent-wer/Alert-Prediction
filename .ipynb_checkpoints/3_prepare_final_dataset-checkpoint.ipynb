# %%
import datetime
import numpy as np
import pandas as pd

import pickle

from utils import tf_idf

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#INPUT_DATA_FOLDER = "data/2_isw_preprocessed"
#REPORTS_DATA_FILE = "all_days_isw_reports_parsed.csv"

#OUTPUT_FOLDER = "data/4_all_data_preprocessed"
#ISW_OUTPUT_DATA_FILE = "all_isw.csv"
#WEATHER_EVENTS_OUTPUT_DATA_FILE = "all_hourly_weather_events.csv"

#MODEL_FOLDER = "model"

#tfidf_transformer_model = "tfidf_transformer"
#count_vectorizer_model = "count_vectorizer"

#tfidf_transformer_version = "v1"
#count_vectorizer_version = "v1"

# %%
def isNaN(num):
    return num != num

# %% [markdown]
# ## reading data

# %%
df_isw = pd.read_csv("data/0_isw_data_collection/2_isw_preprocessed_before_vectosing.csv")

# %%
df_isw = df_isw.drop(columns=['Unnamed: 0.1','Unnamed: 0'],axis=1)

# %%
df_isw.head(5)
# Out:
#          date         short_url  \
# 0  2022-02-25  RusCampaignFeb25
# 1  2022-02-26  RusCampaignFeb26
# 2  2022-02-27  RusCampaignFeb27
# 3  2022-02-28  RusCampaignFeb28
# 4  2022-03-01   RusCampaignMar1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Russian Offensi...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Russian Offensi...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4     Russian Offensive Campaign Assessment, March 1
#
#                                             full_url  \
# 0  /backgrounder/russia-ukraine-warning-update-ru...
# 1  /backgrounder/russia-ukraine-warning-update-ru...
# 2  /backgrounder/russia-ukraine-warning-update-ru...
# 3  /backgrounder/russian-offensive-campaign-asses...
# 4  /backgrounder/russian-offensive-campaign-asses...
#
#                                            main_html  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# 3  <div class="field field-name-body field-type-t...
# 4  <div class="field field-name-body field-type-t...
#
#                                         main_html_v6  \
# 0   Mason Clark, George Barros, and Kateryna Step...
# 1   Mason Clark, George Barros, and Katya Stepane...
# 2   Mason Clark, George Barros, and Kateryna Step...
# 3   Mason Clark, George Barros, and Kateryna Step...
# 4   Frederick W. Kagan, George Barros, and Katery...
#
#                                     report_text_lemm  \
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   mason clark georg barro katya stepanenkofebru...
# 2   mason clark georg barro kateryna stepanenkofe...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   frederick kagan georg barro kateryna stepanen...
#
#                                    report_text_stemm
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   mason clark georg barro katya stepanenkofebru...
# 2   mason clark georg barro kateryna stepanenkofe...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   frederick kagan georg barro kateryna stepanen...

# %% [markdown]
# ## preparing ISW reports

# %% [markdown]
# ## reading models

# %%
#load the content
tfidf = pickle.load(open("models/tfidf_transformer_v1.pkl", "rb"))
cv = pickle.load(open("models/count_vectorizer_v1.pkl", "rb"))

# %%
cv.get_feature_names_out
# Out:
# <bound method CountVectorizer.get_feature_names_out of CountVectorizer(max_df=0.98, min_df=2)>

# %%
df_isw['keywords'] = df_isw['report_text_lemm'].apply(lambda x: tf_idf.convert_doc_to_vector(x,tfidf,cv))

# %%
df_isw.head(5)
# Out:
#          date         short_url  \
# 0  2022-02-25  RusCampaignFeb25
# 1  2022-02-26  RusCampaignFeb26
# 2  2022-02-27  RusCampaignFeb27
# 3  2022-02-28  RusCampaignFeb28
# 4  2022-03-01   RusCampaignMar1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Russian Offensi...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Russian Offensi...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4     Russian Offensive Campaign Assessment, March 1
#
#                                             full_url  \
# 0  /backgrounder/russia-ukraine-warning-update-ru...
# 1  /backgrounder/russia-ukraine-warning-update-ru...
# 2  /backgrounder/russia-ukraine-warning-update-ru...
# 3  /backgrounder/russian-offensive-campaign-asses...
# 4  /backgrounder/russian-offensive-campaign-asses...
#
#                                            main_html  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# 3  <div class="field field-name-body field-type-t...
# 4  <div class="field field-name-body field-type-t...
#
#                                         main_html_v6  \
# 0   Mason Clark, George Barros, and Kateryna Step...
# 1   Mason Clark, George Barros, and Katya Stepane...
# 2   Mason Clark, George Barros, and Kateryna Step...
# 3   Mason Clark, George Barros, and Kateryna Step...
# 4   Frederick W. Kagan, George Barros, and Katery...
#
#                                     report_text_lemm  \
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   mason clark georg barro katya stepanenkofebru...
# 2   mason clark georg barro kateryna stepanenkofe...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   frederick kagan georg barro kateryna stepanen...
#
#                                    report_text_stemm  \
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   mason clark georg barro katya stepanenkofebru...
# 2   mason clark georg barro kateryna stepanenkofe...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   frederick kagan georg barro kateryna stepanen...
#
#                                             keywords
# 0  {'russian': 0.401, 'forc': 0.389, 'februari': ...
# 1  {'russian': 0.406, 'forc': 0.397, 'februari': ...
# 2  {'russian': 0.437, 'forc': 0.437, 'februari': ...
# 3  {'februari': 0.444, 'russian': 0.403, 'forc': ...
# 4  {'russian': 0.367, 'kyiv': 0.301, 'forc': 0.28...

# %%
df_isw["date_datetime"] = pd.to_datetime(df_isw["date"])

# %%
df_isw['date_tomorrow_datetime'] = df_isw['date_datetime'].apply(lambda x: x+datetime.timedelta(days=1))

# %%
df_isw = df_isw.rename(columns = {"date_datetime":"report_date"})
df_isw.to_csv("data/0_isw_data_collection/all_isw.csv", sep=";", index=False)

# %%
df_isw.head(5)
# Out:
#          date         short_url  \
# 0  2022-02-25  RusCampaignFeb25
# 1  2022-02-26  RusCampaignFeb26
# 2  2022-02-27  RusCampaignFeb27
# 3  2022-02-28  RusCampaignFeb28
# 4  2022-03-01   RusCampaignMar1
#
#                                                title  \
# 0  Russia-Ukraine Warning Update: Russian Offensi...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4  Russian Offensive Campaign Assessment, March 1...
#
#                                           text_title  \
# 0  Russia-Ukraine Warning Update: Russian Offensi...
# 1  Russia-Ukraine Warning Update: Russian Offensi...
# 2  Russia-Ukraine Warning Update: Russian Offensi...
# 3  Russian Offensive Campaign Assessment, Februar...
# 4     Russian Offensive Campaign Assessment, March 1
#
#                                             full_url  \
# 0  /backgrounder/russia-ukraine-warning-update-ru...
# 1  /backgrounder/russia-ukraine-warning-update-ru...
# 2  /backgrounder/russia-ukraine-warning-update-ru...
# 3  /backgrounder/russian-offensive-campaign-asses...
# 4  /backgrounder/russian-offensive-campaign-asses...
#
#                                            main_html  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# 3  <div class="field field-name-body field-type-t...
# 4  <div class="field field-name-body field-type-t...
#
#                                         main_html_v6  \
# 0   Mason Clark, George Barros, and Kateryna Step...
# 1   Mason Clark, George Barros, and Katya Stepane...
# 2   Mason Clark, George Barros, and Kateryna Step...
# 3   Mason Clark, George Barros, and Kateryna Step...
# 4   Frederick W. Kagan, George Barros, and Katery...
#
#                                     report_text_lemm  \
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   mason clark georg barro katya stepanenkofebru...
# 2   mason clark georg barro kateryna stepanenkofe...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   frederick kagan georg barro kateryna stepanen...
#
#                                    report_text_stemm  \
# 0   mason clark georg barro kateryna stepanenkofe...
# 1   mason clark georg barro katya stepanenkofebru...
# 2   mason clark georg barro kateryna stepanenkofe...
# 3   mason clark georg barro kateryna stepanenkofe...
# 4   frederick kagan georg barro kateryna stepanen...
#
#                                             keywords report_date  \
# 0  {'russian': 0.401, 'forc': 0.389, 'februari': ...  2022-02-25
# 1  {'russian': 0.406, 'forc': 0.397, 'februari': ...  2022-02-26
# 2  {'russian': 0.437, 'forc': 0.437, 'februari': ...  2022-02-27
# 3  {'februari': 0.444, 'russian': 0.403, 'forc': ...  2022-02-28
# 4  {'russian': 0.367, 'kyiv': 0.301, 'forc': 0.28...  2022-03-01
#
#   date_tomorrow_datetime
# 0             2022-02-26
# 1             2022-02-27
# 2             2022-02-28
# 3             2022-03-01
# 4             2022-03-02

# %% [markdown]
# ## prepare events data

# %%
#EVENTS_DATA_FOLDER = "data/1_events"
#EVENTS_DATA_FILE = "all_events.csv"

# %%
df_events = pd.read_csv("data/alarms_with_features.csv")

# %%
df_events.head()
# Out:
#    Unnamed: 0     id  region_id       region_title             region_city  \
# 0        1218   5257         24  Івано-Франківщина                   Калуш
# 1       19206  45672         24  Івано-Франківщина  Івано-Франківська обл.
# 2       13297  27633         24  Івано-Франківщина  Івано-Франківська обл.
# 3       11354  21845         24  Івано-Франківщина  Івано-Франківська обл.
# 4        3351   5295         24  Івано-Франківщина  Івано-Франківська обл.
#
#    all_region                start                  end            clean_end  \
# 0           0  2022-03-12 10:13:03  2022-03-12 10:26:06  2022-03-12 10:26:06
# 1           1  2022-12-28 11:22:22  2022-12-28 13:20:37  2022-12-28 13:20:37
# 2           1  2022-08-21 03:32:58  2022-08-21 04:03:53  2022-08-21 04:03:53
# 3           1  2022-07-14 10:20:11  2022-07-14 12:12:23  2022-07-14 12:12:23
# 4           1  2022-03-26 21:05:24  2022-03-26 21:42:55  2022-03-26 21:42:55
#
#    intersection_alarm_id           start_time             end_time  day  \
# 0                    NaN  2022-03-12 10:13:03  2022-03-12 10:26:06   12
# 1                    NaN  2022-12-28 11:22:22  2022-12-28 13:20:37   28
# 2                    NaN  2022-08-21 03:32:58  2022-08-21 04:03:53   21
# 3                    NaN  2022-07-14 10:20:11  2022-07-14 12:12:23   14
# 4                    NaN  2022-03-26 21:05:24  2022-03-26 21:42:55   26
#
#    feature_number_of_region      within_24_hours  \
# 0                         0  2022-03-11 10:13:03
# 1                         0  2022-12-27 11:22:22
# 2                         0  2022-08-20 03:32:58
# 3                         0  2022-07-13 10:20:11
# 4                         0  2022-03-25 21:05:24
#
#    feature_number_of_alarms_within_24_hours
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0

# %%
df_events_v2 = df_events.drop(["id","region_id"],axis=1)

# %%
df_events_v2.head(5)
# Out:
#    Unnamed: 0       region_title             region_city  all_region  \
# 0        1218  Івано-Франківщина                   Калуш           0
# 1       19206  Івано-Франківщина  Івано-Франківська обл.           1
# 2       13297  Івано-Франківщина  Івано-Франківська обл.           1
# 3       11354  Івано-Франківщина  Івано-Франківська обл.           1
# 4        3351  Івано-Франківщина  Івано-Франківська обл.           1
#
#                  start                  end            clean_end  \
# 0  2022-03-12 10:13:03  2022-03-12 10:26:06  2022-03-12 10:26:06
# 1  2022-12-28 11:22:22  2022-12-28 13:20:37  2022-12-28 13:20:37
# 2  2022-08-21 03:32:58  2022-08-21 04:03:53  2022-08-21 04:03:53
# 3  2022-07-14 10:20:11  2022-07-14 12:12:23  2022-07-14 12:12:23
# 4  2022-03-26 21:05:24  2022-03-26 21:42:55  2022-03-26 21:42:55
#
#    intersection_alarm_id           start_time             end_time  day  \
# 0                    NaN  2022-03-12 10:13:03  2022-03-12 10:26:06   12
# 1                    NaN  2022-12-28 11:22:22  2022-12-28 13:20:37   28
# 2                    NaN  2022-08-21 03:32:58  2022-08-21 04:03:53   21
# 3                    NaN  2022-07-14 10:20:11  2022-07-14 12:12:23   14
# 4                    NaN  2022-03-26 21:05:24  2022-03-26 21:42:55   26
#
#    feature_number_of_region      within_24_hours  \
# 0                         0  2022-03-11 10:13:03
# 1                         0  2022-12-27 11:22:22
# 2                         0  2022-08-20 03:32:58
# 3                         0  2022-07-13 10:20:11
# 4                         0  2022-03-25 21:05:24
#
#    feature_number_of_alarms_within_24_hours
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0

# %%
# df_events_v2["start_time"] = df_events_v2.apply(lambda x: x["start"] if not isNaN(x["start"]) else x["event_time"] , axis=1)
# df_events_v2["end_time"] = df_events_v2.apply(lambda x: x["end"] if not isNaN(x["end"]) else x["event_time"], axis=1)

# %%
df_events_v2["start_time"] = pd.to_datetime(df_events_v2["start"])
df_events_v2["end_time"] = pd.to_datetime(df_events_v2["end"])
#df_events_v2["event_time"] = pd.to_datetime(df_events_v2["event_time"])

# %%
df_events_v2["start_hour"] = df_events_v2['start_time'].dt.floor('H')
df_events_v2["end_hour"] = df_events_v2['end_time'].dt.ceil('H')
#df_events_v2["event_hour"] = df_events_v2['event_time'].dt.round('H')

# %%
df_events_v2["start_hour"] = df_events_v2.apply(lambda x: x["start_hour"] if not isNaN(x["start_hour"]) else x["event_hour"] , axis=1)
df_events_v2["end_hour"] = df_events_v2.apply(lambda x: x["end_hour"] if not isNaN(x["end_hour"]) else x["event_hour"] , axis=1)

# %%
df_events_v2["day_date"] = df_events_v2["start_time"].dt.date

df_events_v2["start_hour_datetimeEpoch"] = df_events_v2['start_hour'].apply(lambda x: int(x.strftime('%s'))  if not isNaN(x) else None)
df_events_v2["end_hour_datetimeEpoch"] = df_events_v2['end_hour'].apply(lambda x: int(x.strftime('%s'))  if not isNaN(x) else None)

df_events_v2.head(10)
# Out:
#    Unnamed: 0       region_title             region_city  all_region  \
# 0        1218  Івано-Франківщина                   Калуш           0
# 1       19206  Івано-Франківщина  Івано-Франківська обл.           1
# 2       13297  Івано-Франківщина  Івано-Франківська обл.           1
# 3       11354  Івано-Франківщина  Івано-Франківська обл.           1
# 4        3351  Івано-Франківщина  Івано-Франківська обл.           1
# 5       18082  Івано-Франківщина  Івано-Франківська обл.           1
# 6        3350  Івано-Франківщина  Івано-Франківська обл.           1
# 7         238  Івано-Франківщина                   Калуш           0
# 8        1219  Івано-Франківщина        Івано-Франківськ           0
# 9       13259  Івано-Франківщина  Івано-Франківська обл.           1
#
#                  start                  end            clean_end  \
# 0  2022-03-12 10:13:03  2022-03-12 10:26:06  2022-03-12 10:26:06
# 1  2022-12-28 11:22:22  2022-12-28 13:20:37  2022-12-28 13:20:37
# 2  2022-08-21 03:32:58  2022-08-21 04:03:53  2022-08-21 04:03:53
# 3  2022-07-14 10:20:11  2022-07-14 12:12:23  2022-07-14 12:12:23
# 4  2022-03-26 21:05:24  2022-03-26 21:42:55  2022-03-26 21:42:55
# 5  2022-11-17 08:43:21  2022-11-17 10:59:10  2022-11-17 10:59:10
# 6  2022-03-26 21:04:47  2022-03-26 21:42:24  2022-03-26 21:42:24
# 7  2022-03-03 01:52:41  2022-03-03 02:45:57  2022-03-03 02:45:57
# 8  2022-03-12 10:14:24  2022-03-12 10:25:32  2022-03-12 10:25:32
# 9  2022-08-20 14:37:27  2022-08-20 15:13:37  2022-08-20 15:13:37
#
#    intersection_alarm_id          start_time            end_time  day  \
# 0                    NaN 2022-03-12 10:13:03 2022-03-12 10:26:06   12
# 1                    NaN 2022-12-28 11:22:22 2022-12-28 13:20:37   28
# 2                    NaN 2022-08-21 03:32:58 2022-08-21 04:03:53   21
# 3                    NaN 2022-07-14 10:20:11 2022-07-14 12:12:23   14
# 4                    NaN 2022-03-26 21:05:24 2022-03-26 21:42:55   26
# 5                    NaN 2022-11-17 08:43:21 2022-11-17 10:59:10   17
# 6                    NaN 2022-03-26 21:04:47 2022-03-26 21:42:24   26
# 7                    NaN 2022-03-03 01:52:41 2022-03-03 02:45:57    3
# 8                    NaN 2022-03-12 10:14:24 2022-03-12 10:25:32   12
# 9                    NaN 2022-08-20 14:37:27 2022-08-20 15:13:37   20
#
#    feature_number_of_region      within_24_hours  \
# 0                         0  2022-03-11 10:13:03
# 1                         0  2022-12-27 11:22:22
# 2                         0  2022-08-20 03:32:58
# 3                         0  2022-07-13 10:20:11
# 4                         0  2022-03-25 21:05:24
# 5                         0  2022-11-16 08:43:21
# 6                         0  2022-03-25 21:04:47
# 7                         0  2022-03-02 01:52:41
# 8                         0  2022-03-11 10:14:24
# 9                         0  2022-08-19 14:37:27
#
#    feature_number_of_alarms_within_24_hours          start_hour  \
# 0                                         0 2022-03-12 10:00:00
# 1                                         0 2022-12-28 11:00:00
# 2                                         0 2022-08-21 03:00:00
# 3                                         0 2022-07-14 10:00:00
# 4                                         0 2022-03-26 21:00:00
# 5                                         0 2022-11-17 08:00:00
# 6                                         0 2022-03-26 21:00:00
# 7                                         0 2022-03-03 01:00:00
# 8                                         0 2022-03-12 10:00:00
# 9                                         0 2022-08-20 14:00:00
#
#              end_hour    day_date  start_hour_datetimeEpoch  \
# 0 2022-03-12 11:00:00  2022-03-12                1647079200
# 1 2022-12-28 14:00:00  2022-12-28                1672225200
# 2 2022-08-21 05:00:00  2022-08-21                1661050800
# 3 2022-07-14 13:00:00  2022-07-14                1657792800
# 4 2022-03-26 22:00:00  2022-03-26                1648328400
# 5 2022-11-17 11:00:00  2022-11-17                1668672000
# 6 2022-03-26 22:00:00  2022-03-26                1648328400
# 7 2022-03-03 03:00:00  2022-03-03                1646269200
# 8 2022-03-12 11:00:00  2022-03-12                1647079200
# 9 2022-08-20 16:00:00  2022-08-20                1661004000
#
#    end_hour_datetimeEpoch
# 0              1647082800
# 1              1672236000
# 2              1661058000
# 3              1657803600
# 4              1648332000
# 5              1668682800
# 6              1648332000
# 7              1646276400
# 8              1647082800
# 9              1661011200

# %%
df_events_v2.shape
# Out:
# (19933, 19)

# %% [markdown]
# ## prepare weather

# %%
#WEATHER_DATA_FOLDER = "data/1_weather"
#wWEATHER_DATA_FILE = "all_weather_by_hour.csv"

# %%
df_weather = pd.read_csv("data/0_raw_other_data/all_weather_by_hour.csv")
df_weather["day_datetime"] = pd.to_datetime(df_weather["day_datetime"])

# %%
df_weather.shape

# %%
df_weather.head(15)

# %%
# len(clmns)

# %%
# exclude
weather_exclude = [
"day_feelslikemax",
"day_feelslikemin",
"day_sunriseEpoch",
"day_sunsetEpoch",
"day_description",
"city_latitude",
"city_longitude",
"city_address",
"city_timezone",
"city_tzoffset",
"day_feelslike",
"day_precipprob",
"day_snow",
"day_snowdepth",
"day_windgust",
"day_windspeed",
"day_winddir",
"day_pressure",
"day_cloudcover",
"day_visibility",
"day_severerisk",
"day_conditions",
"day_icon",
"day_source",
"day_preciptype",
"day_stations",
"hour_icon",
"hour_source",
"hour_stations",
"hour_feelslike"
]

# %%
# new_list = [x for x in clmns if (x not in weather_exclude)]
# new_list

# %%
df_weather_v2 = df_weather.drop(weather_exclude, axis=1)

# %%
df_weather_v2["city"] = df_weather_v2["city_resolvedAddress"].apply(lambda x: x.split(",")[0])
df_weather_v2["city"] = df_weather_v2["city"].replace('Хмельницька область', "Хмельницький")

# %%
df_weather_v2.head(5)

# %%
df_weather_v2.shape

# %% [markdown]
# ## merging data

# %%
df_regions = pd.read_csv("data/0_raw_other_data/regions.csv")

# %%
df_regions.head(5)

# %%
df_weather_reg = pd.merge(df_weather_v2, df_regions, left_on="city",right_on="center_city_ua")

# %%
df_weather_reg.head(10)

# %%
df_weather_reg.shape

# %%
df_weather_v2.shape

# %% [markdown]
# ### Merging weather and events

# %%
# df_events_v2["start_hour_datetimeEpoch"] = df_events_v2['start_hour'].apply(lambda x: int(x.strftime('%s'))  if not isNaN(x) else 0)
# df_events_v2["end_hour_datetimeEpoch"] = df_events_v2['end_hour'].apply(lambda x: int(x.strftime('%s'))  if not isNaN(x) else 0)

# %%
df_events_v2.dtypes

# %%
df_events_v2.shape

# %%
df_events_v2.head(10)

# %%
# df_events_v2_sample = df_events_v2.sample(10)
# df_events_v2_sample.shape

events_dict = df_events_v2.to_dict('records')
events_by_hour = []

# %%
events_dict[0]

# %%
for event in events_dict:
    for d in pd.date_range(start=event["start_hour"], end=event["end_hour"], freq='1H'):
        et = event.copy()
        et["hour_level_event_time"] = d
        events_by_hour.append(et)

# %%
df_events_v3 = pd.DataFrame.from_dict(events_by_hour)

# %%
df_events_v3["hour_level_event_datetimeEpoch"] = df_events_v3["hour_level_event_time"].apply(lambda x: int(x.strftime('%s'))  if not isNaN(x) else None)

# %%
df_events_v3.shape

# %%
df_events_v3.head(15)

# %%
df_weather_reg.head(5)

# %%
df_weather_reg.shape

# %%
df_events_v3.head(10)

# %%
df_events_v4 = df_events_v3.copy().add_prefix('event_')

# %%
df_weather_reg.head()

# %%
df_weather_reg.to_csv("df_weather_reg.csv")
df_events_v4.to_csv("df_events_v4.csv")

# %%
#df_weather_v4 = df_weather_reg.merge(df_events_v4, 
#                                   how="left", 
#                                   left_on=["region_alt","hour_datetimeEpoch"],
#                                   right_on=["event_region_title","event_hour_level_event_datetimeEpoch"])

# %%
df_weather_v4 = pd.read_csv('data/df_weather_v4.csv')
